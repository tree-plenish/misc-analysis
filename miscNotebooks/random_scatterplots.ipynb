# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %store -r big_df
# %matplotlib inline

# %%
prices = big_df['Tree Price'].to_numpy()
requests = big_df['Tree Requests'].to_numpy()
plt.figure(figsize=(10, 5))
sns.scatterplot(data = big_df, x = 'Tree Price', y='Tree Requests')

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data = big_df, x='Income Percentile By State', y = 'Tree Requests')

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data = big_df, x = 'Income Percentile By State', y='Donations to Requests Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=big_df, x = 'Income Percentile By State', y='Tree Price')

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=big_df, x = 'Income Percentile By State', y='Tree Requests')
